# %%
import pandas as pd
import reverse_geocode

# %%
df = pd.read_csv("significant_earthquakes1965-2016.csv",sep=",")
df.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# ...

# %%
def obtain_country(lat,long):
    c = reverse_geocode.search([(lat,long)])[0]["country"]
    return c

# %%
df["Country"] = df.apply(lambda x: obtain_country(x["Latitude"],x["Longitude"]),axis=1)
df.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  Azimuthal Gap  \
# 0                     NaN        6.0             MW  ...            NaN
# 1                     NaN        5.8             MW  ...            NaN
# 2                     NaN        6.2             MW  ...            NaN
# 3                     NaN        5.8             MW  ...            NaN
# 4                     NaN        5.8             MW  ...            NaN
#
# ...

# %%
pd.set_option('display.max_rows', 500)
df["Country"].value_counts()
# Out:
# Indonesia                                       3080
# Tonga                                           2127
# Japan                                           1802
# Papua New Guinea                                1559
# Russian Federation                              1544
# Chile                                           1262
# Vanuatu                                         1016
# United States                                    982
# Philippines                                      900
# Solomon Islands                                  769
# New Zealand                                      533
# South Georgia and the South Sandwich Islands     532
# Mexico                                           520
# Peru                                             398
# China                                            357
# Wallis and Futuna                                298
# Australia                                        288
# Saint Helena                                     282
# ...

# %%
# export
df.to_csv("significant_earthquakes1965-2016_with_countries.csv",sep=",")
